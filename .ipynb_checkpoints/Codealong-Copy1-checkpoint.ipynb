# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import progressbar

# %%
class Dataset_Handler():

    def __init__(self, sequence, lidar=True, progress_bar=True, low_memory=False):
        
        # This will tell our odometry function if handler contains lidar info
        self.lidar = lidar
        
        # This will tell the odometry function whether images are in lists or generators
        self.low_memory = low_memory
        
        # Set file paths and get ground truth poses
        self.seq_dir = '../dataset/sequences/{}/'.format(sequence)
        self.poses_dir = '../dataset/poses/{}.txt'.format(sequence)
        poses = pd.read_csv(self.poses_dir, delimiter=' ', header=None)
        
        # Get names of files to iterate through
        self.left_image_files = os.listdir(self.seq_dir + 'image_0')
        self.right_image_files = os.listdir(self.seq_dir + 'image_1')
        self.velodyne_files = os.listdir(self.seq_dir + 'velodyne')
        self.num_frames = len(self.left_image_files)
        self.lidar_path = self.seq_dir + 'velodyne/'
        
        # Get calibration details for scene
        # P0 and P1 are Grayscale cams, P2 and P3 are RGB cams
        calib = pd.read_csv(self.seq_dir + 'calib.txt', delimiter=' ', header=None, index_col=0)
        self.P0 = np.array(calib.loc['P0:']).reshape((3,4))
        self.P1 = np.array(calib.loc['P1:']).reshape((3,4))
        self.P2 = np.array(calib.loc['P2:']).reshape((3,4))
        self.P3 = np.array(calib.loc['P3:']).reshape((3,4))
        # This is the transformation matrix for LIDAR
        self.Tr = np.array(calib.loc['Tr:']).reshape((3,4))
        
        # Get times and ground truth poses
        self.times = np.array(pd.read_csv(self.seq_dir + 'times.txt', delimiter=' ', header=None))
        self.gt = np.zeros((len(poses), 3, 4))
        for i in range(len(poses)):
            self.gt[i] = np.array(poses.iloc[i]).reshape((3, 4))
        
        # Get images and lidar loaded
        self.images_left = []
        self.images_right = []
        self.pointclouds = []
        if low_memory:
            #self.images_left = (cv2.imread(seq_dir + 'image_0/' + name_left) for name_left in left_image_files)
            #self.images_right = (cv2.imread(seq_dir + 'image_1' + name_right) for name_right in right_image_files)
            self.reset_frames()
            self.first_image_left = cv2.imread(self.seq_dir + 'image_0/' 
                                               + self.left_image_files[0])
            self.first_image_right = cv2.imread(self.seq_dir + 'image_1/' 
                                                + self.right_image_files[1])
            self.first_pointcloud = np.fromfile(self.lidar_path + self.velodyne_files[0])
            self.imheight = self.first_image_left.shape[0]
            self.imwidth = self.first_image_left.shape[1]
        else:
            if progress_bar:
                import progressbar
                bar = progressbar.ProgressBar(max_value=self.num_frames)
            for i, name_left in enumerate(self.left_image_files):
                name_right = self.right_image_files[i]
                self.images_left.append(cv2.imread(self.seq_dir + 'image_0/' + name_left))
                self.images_right.append(cv2.imread(self.seq_dir + 'image_1/' + name_right))
                if lidar:
                    lidar_path = self.lidar_path + self.velodyne_files[i]
                    pointcloud = np.fromfile(lidar_path, dtype=np.float32, count=-1).reshape([-1,4])
                    self.pointclouds.append(pointcloud)
                if progressbar:
                    bar.update(i+1)
                self.imheight = self.images_left[0].shape[0]
                self.imwidth = self.images_left[0].shape[1]
                
    def reset_frames(self):
        self.images_left = (cv2.imread(self.seq_dir + 'image_0/' + name_left) 
                            for name_left in self.left_image_files)
        self.images_right = (cv2.imread(self.seq_dir + 'image_1' + name_right) 
                             for name_right in self.right_image_files)
        
        self.pointclouds = (np.fromfile(self.lidar_path + velodyne_file, 
                                        dtype=np.float32).reshape([1,4]) 
                            for velodyne_file in self.velodyne_files)
        pass

# %%
handler = Dataset_Handler('00')
# Out:
#   4% (206 of 4541) |                     | Elapsed Time: 0:00:05 ETA:   0:01:54
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-120-a7400f4187de> in <module>
# ----> 1 handler = Dataset_Handler('00')
#
# <ipython-input-119-c5e910266bc8> in __init__(self, sequence, lidar, progress_bar, low_memory)
#      58             for i, name_left in enumerate(self.left_image_files):
#      59                 name_right = self.right_image_files[i]
# ---> 60                 self.images_left.append(cv2.imread(self.seq_dir + 'image_0/' + name_left))
#      61                 self.images_right.append(cv2.imread(self.seq_dir + 'image_1/' + name_right))
#      62                 if lidar:
#
# KeyboardInterrupt:

# %%
handler2 = Dataset_Handler('00', low_memory=True)

# %%
plt.imshow(handler2.first_image_left)
plt.show()

# %%
import datetime

# %%
handler2.reset_frames()
for i in range(1000):
    start = datetime.datetime.now()
    cv2.imshow('frame', next(handler2.images_left))
    end = datetime.datetime.now()
    print('Time to load image:', end-start)
    cv2.waitKey(10)
cv2.destroyAllWindows()
# Out:
# Time to load image: 0:00:00.148993
# Time to load image: 0:00:00.018003
# Time to load image: 0:00:00.017000
# Time to load image: 0:00:00.012998
# Time to load image: 0:00:00.015001
# Time to load image: 0:00:00.017014
# Time to load image: 0:00:00.013994
# Time to load image: 0:00:00.016001
# Time to load image: 0:00:00.015003
# Time to load image: 0:00:00.011993
# Time to load image: 0:00:00.012004
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.012005
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.011005
# Time to load image: 0:00:00.013973
# Time to load image: 0:00:00.012003
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.009998
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.010992
# Time to load image: 0:00:00.011012
# Time to load image: 0:00:00.011997
# Time to load image: 0:00:00.012969
# Time to load image: 0:00:00.014997
# Time to load image: 0:00:00.014002
# Time to load image: 0:00:00.010002
# Time to load image: 0:00:00.012002
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.012005
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.013001
# Time to load image: 0:00:00.010007
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.011999
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.010000
# Time to load image: 0:00:00.009994
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.013005
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.010002
# Time to load image: 0:00:00.012002
# Time to load image: 0:00:00.010026
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.011993
# Time to load image: 0:00:00.011033
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.014995
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.013000
# Time to load image: 0:00:00.011973
# Time to load image: 0:00:00.010003
# Time to load image: 0:00:00.011970
# Time to load image: 0:00:00.010980
# Time to load image: 0:00:00.010966
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.012995
# Time to load image: 0:00:00.010975
# Time to load image: 0:00:00.012002
# Time to load image: 0:00:00.010004
# Time to load image: 0:00:00.011999
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.011006
# Time to load image: 0:00:00.012005
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.010972
# Time to load image: 0:00:00.011996
# Time to load image: 0:00:00.010967
# Time to load image: 0:00:00.010995
# Time to load image: 0:00:00.010966
# Time to load image: 0:00:00.011999
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.010996
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.011998
# Time to load image: 0:00:00.010003
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.012001
# Time to load image: 0:00:00.010966
# Time to load image: 0:00:00.010000
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.012001
# Time to load image: 0:00:00.013004
# Time to load image: 0:00:00.011970
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.010992
# Time to load image: 0:00:00.014997
# Time to load image: 0:00:00.013998
# Time to load image: 0:00:00.011999
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.012997
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.012004
# Time to load image: 0:00:00.010995
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.011967
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.012003
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.012009
# Time to load image: 0:00:00.011996
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.010972
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.011005
# Time to load image: 0:00:00.010966
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.012003
# Time to load image: 0:00:00.014971
# Time to load image: 0:00:00.011034
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.012005
# Time to load image: 0:00:00.014006
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.013003
# Time to load image: 0:00:00.013009
# Time to load image: 0:00:00.014000
# Time to load image: 0:00:00.013001
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.011009
# Time to load image: 0:00:00.011998
# Time to load image: 0:00:00.010967
# Time to load image: 0:00:00.013005
# Time to load image: 0:00:00.010001
# Time to load image: 0:00:00.012003
# Time to load image: 0:00:00.010995
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.013000
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.011008
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.011999
# Time to load image: 0:00:00.012001
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.010001
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.011996
# Time to load image: 0:00:00.012009
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.012001
# Time to load image: 0:00:00.010995
# Time to load image: 0:00:00.013970
# Time to load image: 0:00:00.010000
# Time to load image: 0:00:00.010000
# Time to load image: 0:00:00.011972
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.010006
# Time to load image: 0:00:00.010000
# Time to load image: 0:00:00.010967
# Time to load image: 0:00:00.014001
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011967
# Time to load image: 0:00:00.011034
# Time to load image: 0:00:00.013970
# Time to load image: 0:00:00.012997
# Time to load image: 0:00:00.010973
# Time to load image: 0:00:00.013972
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.012030
# Time to load image: 0:00:00.009996
# Time to load image: 0:00:00.012002
# Time to load image: 0:00:00.010996
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.011006
# Time to load image: 0:00:00.010968
# Time to load image: 0:00:00.013008
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.011968
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.010962
# Time to load image: 0:00:00.013964
# Time to load image: 0:00:00.010996
# Time to load image: 0:00:00.011006
# Time to load image: 0:00:00.010996
# Time to load image: 0:00:00.012004
# Time to load image: 0:00:00.010966
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.011964
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.010002
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.011007
# Time to load image: 0:00:00.013963
# Time to load image: 0:00:00.012006
# Time to load image: 0:00:00.010983
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.014003
# Time to load image: 0:00:00.015004
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.010968
# Time to load image: 0:00:00.009994
# Time to load image: 0:00:00.010968
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.010001
# Time to load image: 0:00:00.012001
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.011010
# Time to load image: 0:00:00.010996
# Time to load image: 0:00:00.010003
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.009971
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.010971
# Time to load image: 0:00:00.012002
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.010006
# Time to load image: 0:00:00.011031
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.010968
# Time to load image: 0:00:00.013004
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.013970
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.010972
# Time to load image: 0:00:00.011967
# Time to load image: 0:00:00.010031
# Time to load image: 0:00:00.012002
# Time to load image: 0:00:00.010968
# Time to load image: 0:00:00.011969
# Time to load image: 0:00:00.012001
# Time to load image: 0:00:00.014972
# Time to load image: 0:00:00.010966
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.011966
# Time to load image: 0:00:00.010973
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.012035
# Time to load image: 0:00:00.011970
# Time to load image: 0:00:00.011981
# Time to load image: 0:00:00.010968
# Time to load image: 0:00:00.011966
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.009997
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.012005
# Time to load image: 0:00:00.009999
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.010994
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.014002
# Time to load image: 0:00:00.010002
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.010003
# Time to load image: 0:00:00.012002
# Time to load image: 0:00:00.011996
# Time to load image: 0:00:00.011998
# Time to load image: 0:00:00.011998
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.015002
# Time to load image: 0:00:00.011999
# Time to load image: 0:00:00.012002
# Time to load image: 0:00:00.013002
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.013005
# Time to load image: 0:00:00.016000
# Time to load image: 0:00:00.011999
# Time to load image: 0:00:00.012003
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011996
# Time to load image: 0:00:00.010004
# Time to load image: 0:00:00.011005
# Time to load image: 0:00:00.011966
# Time to load image: 0:00:00.010034
# Time to load image: 0:00:00.012029
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.010967
# Time to load image: 0:00:00.010967
# Time to load image: 0:00:00.011010
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.009998
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.012991
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.013969
# Time to load image: 0:00:00.010992
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.010975
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.010002
# Time to load image: 0:00:00.010971
# Time to load image: 0:00:00.011005
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.011971
# Time to load image: 0:00:00.011972
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.012998
# Time to load image: 0:00:00.010972
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.012005
# Time to load image: 0:00:00.010028
# Time to load image: 0:00:00.012002
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.009999
# Time to load image: 0:00:00.009997
# Time to load image: 0:00:00.010971
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.009991
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.011996
# Time to load image: 0:00:00.011005
# Time to load image: 0:00:00.010006
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.010002
# Time to load image: 0:00:00.012004
# Time to load image: 0:00:00.010960
# Time to load image: 0:00:00.011010
# Time to load image: 0:00:00.010993
# Time to load image: 0:00:00.009965
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.010996
# Time to load image: 0:00:00.010966
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.010001
# Time to load image: 0:00:00.012002
# Time to load image: 0:00:00.011997
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.009998
# Time to load image: 0:00:00.011996
# Time to load image: 0:00:00.010971
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.010003
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.012998
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.011006
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.012970
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.010973
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.010005
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.011964
# Time to load image: 0:00:00.009974
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011998
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.009997
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.010966
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.010967
# Time to load image: 0:00:00.009972
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.011998
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.010001
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.009994
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.011966
# Time to load image: 0:00:00.010977
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.010001
# Time to load image: 0:00:00.010966
# Time to load image: 0:00:00.013001
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.010967
# Time to load image: 0:00:00.012999
# Time to load image: 0:00:00.015032
# Time to load image: 0:00:00.010965
# Time to load image: 0:00:00.009999
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011006
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.009973
# Time to load image: 0:00:00.010968
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.009970
# Time to load image: 0:00:00.009970
# Time to load image: 0:00:00.010995
# Time to load image: 0:00:00.010967
# Time to load image: 0:00:00.010965
# Time to load image: 0:00:00.009999
# Time to load image: 0:00:00.011006
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.009997
# Time to load image: 0:00:00.010968
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.011970
# Time to load image: 0:00:00.011008
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.010971
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.010995
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011997
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.015001
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.011965
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.012001
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011005
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.014005
# Time to load image: 0:00:00.010971
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.013000
# Time to load image: 0:00:00.010030
# Time to load image: 0:00:00.010996
# Time to load image: 0:00:00.011007
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.012999
# Time to load image: 0:00:00.011972
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.010971
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.010004
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.010971
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.010994
# Time to load image: 0:00:00.011966
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.010973
# Time to load image: 0:00:00.010001
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.009999
# Time to load image: 0:00:00.011965
# Time to load image: 0:00:00.010965
# Time to load image: 0:00:00.010968
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.010967
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.010964
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011966
# Time to load image: 0:00:00.011925
# Time to load image: 0:00:00.010967
# Time to load image: 0:00:00.012004
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.010995
# Time to load image: 0:00:00.011970
# Time to load image: 0:00:00.015000
# Time to load image: 0:00:00.012003
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.009995
# Time to load image: 0:00:00.010972
# Time to load image: 0:00:00.010965
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.012995
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.011008
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.012003
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.011007
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.010002
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.014997
# Time to load image: 0:00:00.011999
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011969
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.010972
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.012008
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.009994
# Time to load image: 0:00:00.012999
# Time to load image: 0:00:00.010000
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.010974
# Time to load image: 0:00:00.012996
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.016968
# Time to load image: 0:00:00.011005
# Time to load image: 0:00:00.012999
# Time to load image: 0:00:00.010996
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011005
# Time to load image: 0:00:00.013000
# Time to load image: 0:00:00.010995
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.010994
# Time to load image: 0:00:00.011008
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.012999
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.014966
# Time to load image: 0:00:00.011014
# Time to load image: 0:00:00.012001
# Time to load image: 0:00:00.011969
# Time to load image: 0:00:00.010966
# Time to load image: 0:00:00.010968
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.011969
# Time to load image: 0:00:00.015004
# Time to load image: 0:00:00.010968
# Time to load image: 0:00:00.010981
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.012996
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.013977
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.010000
# Time to load image: 0:00:00.014003
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011013
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.013973
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.013001
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.012004
# Time to load image: 0:00:00.011999
# Time to load image: 0:00:00.010968
# Time to load image: 0:00:00.015004
# Time to load image: 0:00:00.012004
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.010008
# Time to load image: 0:00:00.011966
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.013008
# Time to load image: 0:00:00.012996
# Time to load image: 0:00:00.014000
# Time to load image: 0:00:00.011006
# Time to load image: 0:00:00.011999
# Time to load image: 0:00:00.011005
# Time to load image: 0:00:00.012999
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.013004
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.012999
# Time to load image: 0:00:00.011994
# Time to load image: 0:00:00.012001
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.012003
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.010001
# Time to load image: 0:00:00.013003
# Time to load image: 0:00:00.012970
# Time to load image: 0:00:00.011996
# Time to load image: 0:00:00.009995
# Time to load image: 0:00:00.011969
# Time to load image: 0:00:00.013004
# Time to load image: 0:00:00.011995
# Time to load image: 0:00:00.010995
# Time to load image: 0:00:00.009967
# Time to load image: 0:00:00.012996
# Time to load image: 0:00:00.010002
# Time to load image: 0:00:00.012006
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.010974
# Time to load image: 0:00:00.011967
# Time to load image: 0:00:00.011007
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.010995
# Time to load image: 0:00:00.011968
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.010031
# Time to load image: 0:00:00.014970
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.011005
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.012994
# Time to load image: 0:00:00.010973
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.011968
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011005
# Time to load image: 0:00:00.012030
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.012999
# Time to load image: 0:00:00.010971
# Time to load image: 0:00:00.010966
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.011994
# Time to load image: 0:00:00.010008
# Time to load image: 0:00:00.011965
# Time to load image: 0:00:00.015001
# Time to load image: 0:00:00.013001
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.011972
# Time to load image: 0:00:00.010968
# Time to load image: 0:00:00.010005
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.012005
# Time to load image: 0:00:00.012002
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.014001
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.011009
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.010996
# Time to load image: 0:00:00.012005
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.014995
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.010968
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.010960
# Time to load image: 0:00:00.011965
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.010966
# Time to load image: 0:00:00.010965
# Time to load image: 0:00:00.010006
# Time to load image: 0:00:00.010968
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.010971
# Time to load image: 0:00:00.011007
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.012005
# Time to load image: 0:00:00.012998
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.014967
# Time to load image: 0:00:00.011006
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.010994
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.014001
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.012002
# Time to load image: 0:00:00.013007
# Time to load image: 0:00:00.011997
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.012999
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.013001
# Time to load image: 0:00:00.010996
# Time to load image: 0:00:00.011971
# Time to load image: 0:00:00.013000
# Time to load image: 0:00:00.009967
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.009994
# Time to load image: 0:00:00.010966
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.010967
# Time to load image: 0:00:00.011969
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011031
# Time to load image: 0:00:00.010966
# Time to load image: 0:00:00.011997
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.010964
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.010002
# Time to load image: 0:00:00.011967
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.010972
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.016000
# Time to load image: 0:00:00.011019
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.012006
# Time to load image: 0:00:00.012002
# Time to load image: 0:00:00.011969
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.015999
# Time to load image: 0:00:00.010975
# Time to load image: 0:00:00.012003
# Time to load image: 0:00:00.011005
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011029
# Time to load image: 0:00:00.012003
# Time to load image: 0:00:00.011965
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.011005
# Time to load image: 0:00:00.011973
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.012005
# Time to load image: 0:00:00.011007
# Time to load image: 0:00:00.010000
# Time to load image: 0:00:00.010971
# Time to load image: 0:00:00.013001
# Time to load image: 0:00:00.010996
# Time to load image: 0:00:00.010967
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.011968
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.012001
# Time to load image: 0:00:00.009995
# Time to load image: 0:00:00.011999
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.009996
# Time to load image: 0:00:00.012005
# Time to load image: 0:00:00.010996
# Time to load image: 0:00:00.010996
# Time to load image: 0:00:00.009961
# Time to load image: 0:00:00.010972
# Time to load image: 0:00:00.013968
# Time to load image: 0:00:00.011964
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.012010
# Time to load image: 0:00:00.014002
# Time to load image: 0:00:00.011006
# Time to load image: 0:00:00.011034
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.016003
# Time to load image: 0:00:00.010971
# Time to load image: 0:00:00.013000
# Time to load image: 0:00:00.010971
# Time to load image: 0:00:00.012003
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.009999
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.009997
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.010991
# Time to load image: 0:00:00.012027
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.010967
# Time to load image: 0:00:00.010968
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.010995
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.013000
# Time to load image: 0:00:00.009998
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.009968
# Time to load image: 0:00:00.011006
# Time to load image: 0:00:00.011970
# Time to load image: 0:00:00.011965
# Time to load image: 0:00:00.011999
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.010967
# Time to load image: 0:00:00.010967
# Time to load image: 0:00:00.010001
# Time to load image: 0:00:00.011998
# Time to load image: 0:00:00.013964
# Time to load image: 0:00:00.012002
# Time to load image: 0:00:00.009968
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.013972
# Time to load image: 0:00:00.011991
# Time to load image: 0:00:00.010004
# Time to load image: 0:00:00.013004
# Time to load image: 0:00:00.010000
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.009996
# Time to load image: 0:00:00.012005
# Time to load image: 0:00:00.013003
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.012973
# Time to load image: 0:00:00.010995
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.010968
# Time to load image: 0:00:00.010970
# Time to load image: 0:00:00.012005
# Time to load image: 0:00:00.010967
# Time to load image: 0:00:00.012970
# Time to load image: 0:00:00.010995
# Time to load image: 0:00:00.011009
# Time to load image: 0:00:00.010996
# Time to load image: 0:00:00.011960
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.010961
# Time to load image: 0:00:00.011965
# Time to load image: 0:00:00.014005
# Time to load image: 0:00:00.011964
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.013001
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.010995
# Time to load image: 0:00:00.014005
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.011999
# Time to load image: 0:00:00.012001
# Time to load image: 0:00:00.014003
# Time to load image: 0:00:00.014996
# Time to load image: 0:00:00.012994
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.014974
# Time to load image: 0:00:00.010972
# Time to load image: 0:00:00.011999
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.011999
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.010973
# Time to load image: 0:00:00.013000
# Time to load image: 0:00:00.012001
# Time to load image: 0:00:00.015004
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.010992
# Time to load image: 0:00:00.011031
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.011492
# Time to load image: 0:00:00.011997
# Time to load image: 0:00:00.010974
# Time to load image: 0:00:00.012002
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.011032
# Time to load image: 0:00:00.010996
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.010996
# Time to load image: 0:00:00.014996
# Time to load image: 0:00:00.012034
# Time to load image: 0:00:00.011010
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.010972
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.010001
# Time to load image: 0:00:00.013000
# Time to load image: 0:00:00.011004
# Time to load image: 0:00:00.011006
# Time to load image: 0:00:00.011000
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.015999
# Time to load image: 0:00:00.011999
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.011999
# Time to load image: 0:00:00.011003
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.013000
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.011002
# Time to load image: 0:00:00.013005
# Time to load image: 0:00:00.010995
# Time to load image: 0:00:00.013001
# Time to load image: 0:00:00.011001
# Time to load image: 0:00:00.012000
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.012002
# Time to load image: 0:00:00.010963
# Time to load image: 0:00:00.010998
# Time to load image: 0:00:00.012004
# Time to load image: 0:00:00.015005
# Time to load image: 0:00:00.011971
# Time to load image: 0:00:00.011995
# Time to load image: 0:00:00.010966
# Time to load image: 0:00:00.013001
# Time to load image: 0:00:00.010962
# Time to load image: 0:00:00.010960
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.011968
# Time to load image: 0:00:00.012007
# Time to load image: 0:00:00.011966
# Time to load image: 0:00:00.012010
# Time to load image: 0:00:00.010971
# Time to load image: 0:00:00.010969
# Time to load image: 0:00:00.010999
# Time to load image: 0:00:00.011969
# Time to load image: 0:00:00.015002
# Time to load image: 0:00:00.010997
# Time to load image: 0:00:00.011999
# Time to load image: 0:00:00.012003
# Time to load image: 0:00:00.012003
# Time to load image: 0:00:00.012002
# Time to load image: 0:00:00.014001
# Time to load image: 0:00:00.011015
# Time to load image: 0:00:00.011002

# %%
for i in range(1000):
    start = datetime.datetime.now()
    cv2.imshow('frame', handler.images_left[i])
    end = datetime.datetime.now()
    print('Time to load image:', end-start)
    cv2.waitKey(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a6204a11604d> in <module>
#       1 for i in range(1000):
#       2     start = datetime.datetime.now()
# ----> 3     cv2.imshow('frame', handler.images_left[i])
#       4     end = datetime.datetime.now()
#       5     print('Time to load image:', end-start)
#
# NameError: name 'handler' is not defined

# %%
import gc

# %%
del(handler)
gc.collect()
# Out:
# 27

# %%
cv2.imshow('frame', handler.pointclouds[0])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# %matplotlib notebook

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
xs=handler.pointclouds[0][:, 0][::5] 
ys=handler.pointclouds[0][:, 1][::5]
zs=handler.pointclouds[0][:, 2][::5]
ax = plt.axes(projection='3d')

ax.set_box_aspect((np.ptp(xs), np.ptp(ys), np.ptp(zs)))

ax.scatter(xs, ys, zs, s=0.1)
ax.view_init(elev=40, azim=180)
ax.grid(False)
ax.axis('off')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5, 0, 'z')

# %%
plt.figure()
plt.imshow(handler.images_left[0])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
